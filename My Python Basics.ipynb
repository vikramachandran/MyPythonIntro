# %%
print(9**2)
print(9.0)
int(10/4)
# Out:
# 81
# 9.0
# 2

# %%
manila_pop = 1781573
manila_area = 16.56
manila_pop_density = manila_pop/manila_area
print(int(manila_pop_density))
# Out:
# 107582

# %%
sf_population, sf_area = 864816, 231.89
rio_population, rio_area = 6453682, 486.5

san_francisco_pop_density = sf_population/sf_area
rio_de_janeiro_pop_density = rio_population/rio_area
print(san_francisco_pop_density)
print(rio_de_janeiro_pop_density)

print(san_francisco_pop_density > rio_de_janeiro_pop_density)
# Out:
# 3729.42343352
# 13265.5334018
# False

# %%
salesman = '\"I think you\'re an encyclopaedia salesman\"'
print(salesman)
messiah ='He\'s not the Messiah, he\'s a very naughty boy!'
print(messiah)
# Out:
# "I think you're an encyclopaedia salesman"
# He's not the Messiah, he's a very naughty boy!

# %%
def cylinder_volume(height, radius):
    pi = 3.14159
    return height * pi * radius ** 2

# %%
cylinder_volume(10, 3)
# Out:
# 282.7431

# %%
# todo: define a function named `population_density` that takes two arguments, 
# `population` and `land_area` (in square kilometres), and returns a population 
# density calculated from those values.

# Your code goes here!

def population_density(population,land_area):
    return(population/land_area)
    
# Here are test cases to verify that your function works as expected:
test1 = population_density(10, 1)
expected_result1 = 10
print("expected result: {}, actual result: {}".format(expected_result1, test1))

test2 = population_density(864816, 121.4)
expected_result2 = 7123.6902801
print("expected result: {}..., actual result: {}".format(expected_result2, test2))
# Out:
# expected result: 10, actual result: 10
# expected result: 7123.6902801..., actual result: 7123.69028007

# %%
def print_testcase(expected_value, actual_value):
    print("expected value: {}, actual value: {}".format(expected_value, actual_value))

# %%
return_value = print_testcase(42, 42)
# Out:
# expected value: 42, actual value: 42

# %%
def readable_timedelta(days):
    weeks = int(days/7)
    leftoverdays = days%7
    return("{} weeks(s) and {} days".format(weeks,leftoverdays))

test = readable_timedelta(200)
print(test)
# Out:
# 28 weeks(s) and 4 days

# %%
how_many_snakes = 1
snake_string = """
Welcome to Python3!

             ____
            / . .\\
            \  ---<
             \  /
   __________/ /
-=:___________/

<3, Philip and Charlie
"""


print(snake_string * how_many_snakes)
# Out:
# Welcome to Python3!
#
#              ____
#             / . .\
#             \  ---<
#              \  /
#    __________/ /
# -=:___________/
#
# <3, Philip and Charlie

# %%
def which_prize(points):
    if (points >= 0 and points <= 50):
        print("Congratulations! You have won a {}!".format("wooden rabbit"))
    elif (points >= 51 and points <= 150):
        print("Oh dear, no prize this time.")
    elif (points >= 151 and points <= 180):
        print("Congratulations! You have won a {}!".format("wafer-thin mint"))
    elif (points >= 181 and points <= 200):
        print("Congratulations! You have won a {}!".format("wafer-thin mint"))
    else:
        print("Oh dear, no prize this time.")

# %%
which_prize(190)
# Out:
# Congratulations! You have won a wafer-thin mint!

# %%
def cylinder_surface_area(radius, height, has_top_and_bottom):
    side_area = height * 6.28 * radius
    if not has_top_and_bottom:
        return side_area
    else:
        top_area = 3.14 * radius ** 2
        side_area += 2 * top_area
        return side_area

# %%
print(cylinder_surface_area(3,10,False))
# Out:
# 188.4

# %%
def which_prize(points):
    prize = None
    if (points >= 0 and points <= 50):
        prize = "wooden rabbit"
    elif (points >= 151 and points <= 180):
        prize = "wafer-thin mint"
    elif (points >= 181 and points <= 200):
        prize = "penguin"
    
    if prize:
        return("Congratulations! You have won a prize = {}!".format(prize))
    else:
        return("Oh dear, no prize this time.")
        
print(which_prize(194))
# Out:
# Congratulations! You have won a prize = penguin!

# %%
def convert_to_numeric(score):
    score_type = type(score)
    if (score_type == "int"):
        return score
    else: 
        return int(score)

def sum_of_middle_three(score1,score2,score3,score4,score5):
    sum_temp = [score1,score2,score3,score4,score5]
    print(sum_temp)
    print(sum(sum_temp),min(sum_temp),max(sum_temp))
    fin_sum = sum(sum_temp)-min(sum_temp)-max(sum_temp)
    return(fin_sum)
    
    
def score_to_rating_string(average_score):
    if (average_score >=0 and average_score <1):
        return "Terrible"
    elif (average_score >=1 and average_score <2):
        return "Bad"
    elif (average_score >=2 and average_score <3):
        return "OK"
    elif (average_score >=3 and average_score <4):
        return "Good"
    else:
        return "Excellent"
    

def scores_to_rating(score1,score2,score3,score4,score5):
    """
    Turns five scores into a rating by averaging the
    middle three of the five scores and assigning this average
    to a written rating.
    """
    #STEP 1 convert scores to numbers
    score1 = convert_to_numeric(score1)
    score2 = convert_to_numeric(score2)
    score3 = convert_to_numeric(score3)
    score4 = convert_to_numeric(score4)
    score5 = convert_to_numeric(score5)

    #STEP 2 and STEP 3 find the average of the middle three scores
    average_score = sum_of_middle_three(score1,score2,score3, \
                                        score4,score5)/3

    #STEP 4 turn average score into a rating
    rating = score_to_rating_string(average_score)

    return rating

print(scores_to_rating(1,"14","14",2,1))
# Out:
# [1, 14, 14, 2, 1]
# (32, 1, 14)
# Excellent

# %%
eclipse_dates = ['June 21, 2001', 'December 4, 2002', 'November 23, 2003',
                 'March 29, 2006', 'August 1, 2008', 'July 22, 2009',
                 'July 11, 2010', 'November 13, 2012', 'March 20, 2015',
                 'March 9, 2016']
                 
                 
# TODO: Modify this line so it prints the last three elements of the list
print(eclipse_dates[-3:])
print("=======================")
print(eclipse_dates[2:])
print("=======================")
print(eclipse_dates[:2])
# Out:
# ['November 13, 2012', 'March 20, 2015', 'March 9, 2016']
# ...
# ['November 23, 2003', 'March 29, 2006', 'August 1, 2008', 'July 22, 2009', 'July 11, 2010', 'November 13, 2012', 'March 20, 2015', 'March 9, 2016']
# ...
# ['June 21, 2001', 'December 4, 2002']

# %%
nautical_directions = "\n".join(["fore", "aft", "starboard", "port"])

# %%
print(nautical_directions)
# Out:
# fore
# aft
# starboard
# port

# %%
def top_three(input_list):
    print(input_list)
    input_list = sorted(input_list,reverse=True)
    print(input_list)
    return(input_list[:3])

top_three([2,3,5,6,8,4,2,1])
# Out:
# [2, 3, 5, 6, 8, 4, 2, 1]
# [8, 6, 5, 4, 3, 2, 2, 1]
# [8, 6, 5]

# %%
def median(numbers):
    numbers.sort() #The sort method sorts a list directly, rather than returning a new sorted list
    middle_index = int(len(numbers)/2)
    #print(middle_index)
    if (len(numbers)%2 == 1):
        #print(numbers[middle_index])
        return numbers[middle_index]
        
    else:
        #print(numbers[middle_index-1])
        #print(numbers[middle_index])
        #test = numbers[middle_index]+numbers[middle_index-1]
        #print(test)
        return float(numbers[middle_index]+numbers[middle_index-1])/2
    
test2 = median([1,2,3,4])
print("expected result: 2.5, actual result: {}".format(test2))
    
test1 = median([1,2,3])
print("expected result: 2, actual result: {}".format(test1))

test3 = median([53, 12, 65, 7, 420, 317, 88])
print("expected result: 65, actual result: {}".format(test3))
# Out:
# 2
# 2
# 3
# 5
# expected result: 2.5, actual result: 2.5
# 1
# 2
# expected result: 2, actual result: 2
# 3
# 65
# expected result: 65, actual result: 65

# %%
numbers = [1,2,3,4]
print(len(numbers)//2)
print(len(numbers)/2)
print(int(len(numbers)/2))
print(len(numbers)%2)
# Out:
# 2
# 2
# 2
# 0

# %%
def tag_count(input_list):
    cnt = 0
    for element in input_list:
        leng = len(element) - 1
        if( element[0] == '<' and element[leng] == '>'):
            # or element[-1] == '>'
           cnt += 1 
    return cnt
    
    


# Test for the tag_count function:
list1 = ['<greeting>', 'Hello World!', '</greeting>']
count = tag_count(list1)
print count
# Out:
# 2

# %%
names = ['charlotte hippopotamus turner', 'oliver st. john-mollusc', 'nigel incubator-jones', 'philip diplodocus mallory']

for name in names:
    name = name.title()

print(names)
# Out:
# ['charlotte hippopotamus turner', 'oliver st. john-mollusc', 'nigel incubator-jones', 'philip diplodocus mallory']

# %%
names = ['charlotte hippopotamus turner', 'oliver st. john-mollusc',
         'nigel incubator-jones', 'philip diplodocus mallory']
# create a new list of capitalized names without modifying the original list
capitalized_names = [] #create a new, empty list
for name in names:
    capitalized_names.append(name.title()) #add elements to the new list

print(names)
print(capitalized_names)
# Out:
# ['charlotte hippopotamus turner', 'oliver st. john-mollusc', 'nigel incubator-jones', 'philip diplodocus mallory']
# ['Charlotte Hippopotamus Turner', 'Oliver St. John-Mollusc', 'Nigel Incubator-Jones', 'Philip Diplodocus Mallory']

# %%
names = ['charlotte hippopotamus turner', 'oliver st. john-mollusc',
         'nigel incubator-jones', 'philip diplodocus mallory']

print(names)
# modify the names list in place
for index in range(len(names)): # iterate over the index numbers of the names list
    names[index] = names[index].title() # modify each element of names
print(names)
# Out:
# ['charlotte hippopotamus turner', 'oliver st. john-mollusc', 'nigel incubator-jones', 'philip diplodocus mallory']
# ['Charlotte Hippopotamus Turner', 'Oliver St. John-Mollusc', 'Nigel Incubator-Jones', 'Philip Diplodocus Mallory']

# %%
print(range(len(names)))
# Out:
# [0, 1, 2, 3]

# %%
#define the  html_list function
def html_list(input_list):
    out_str = []
    out_str.append("<ul>")
    for element in input_list:
        out_str.append("<li>"+element+"</li>")
    out_str.append("</ul>")
    res_str = "\n".join(out_str)
    print(out_str)
    print(res_str)
    return(res_str)

print(html_list(['first string', 'second string']))
# Out:
# ['<ul>', '<li>first string</li>', '<li>second string</li>', '</ul>']
# <ul>
# <li>first string</li>
# <li>second string</li>
# </ul>
# <ul>
# <li>first string</li>
# <li>second string</li>
# </ul>

# %%
nautical_directions = "\n".join(["fore", "aft", "starboard", "port"])
>>> print(nautical_directions)
# Out:
# fore
# aft
# starboard
# port

# %%
def html_list(list_items):
    HTML_string = "<ul>\n"
    for item in list_items:
        HTML_string += "<li>{}</li>\n".format(item)
    HTML_string += "</ul>"
    return HTML_string

# %%
def starbox(width, height):
    """print a box made up of asterisks.

    width: width of box in characters, must be at least 2
    height: height of box in lines, must be at least 2
    """
    print("*" * width) #print top edge of box
   
    # print sides of box
    # todo: print this line height-2 times, instead of three times
    print("*" + " " * (width-2) + "*") 
    print("*" + " " * (width-2) + "*")
    print("*" + " " * (width-2) + "*")

    print("*" * width) #print bottom edge of box

# Test Cases
print("Test 1:")
starbox(5, 5) # this prints correctly

print("Test 2:")
starbox(2, 3)  # this currently prints two lines too tall - fix it!
# Out:
# Test 1:
# *****
# *   *
# *   *
# *   *
# *****
# Test 2:
# **
# **
# **
# **
# **

# %%
def starbox(width, height):
    """print a box made up of asterisks.

    width: width of box in characters, must be at least 2
    height: height of box in lines, must be at least 2
    """
    print("*" * width) #print top edge of box
   
    # print sides of box
    # todo: print this line height-2 times, instead of three times
    for i in range(height-2):
        print("*" + " " * (width-2) + "*") 
        #print("*" + " " * (width-2) + "*")
        #print("*" + " " * (width-2) + "*")

    print("*" * width) #print bottom edge of box

# Test Cases
print("Test 1:")
starbox(5, 5) # this prints correctly

print("Test 2:")
starbox(2, 3)  # this currently prints two lines too tall - fix it!
# Out:
# Test 1:
# *****
# *   *
# *   *
# *   *
# *****
# Test 2:
# **
# **
# **

# %%
def starbox(width, height):
    """print a box made up of asterisks.

    width: width of box in characters, must be at least 2
    height: height of box in lines, must be at least 2
    """
    print("*" * width) #print top edge of box

    # print sides of box
    for _ in range(height-2):
        print("*" + " " * (width-2) + "*") 

    print("*" * width) #print bottom edge of box

# %%
card_deck = [4, 11, 8, 5, 13, 2, 8, 10]
hand = []

while sum(hand) <= 17:
    hand.append(card_deck.pop())

print(hand)
# Out:
# [10, 8]

# %%
def nearest_square(limit):
    answer = 0
    while (answer+1)**2 < limit:
        answer += 1
    return answer**2

# %%
def nearest_square(limit):
    sqnum = 1
    result = 0
    while(result < limit):
        result = sqnum**2
        sqnum += 1
    print(sqnum)
    result = (sqnum-2)**2
    return result

test1 = nearest_square(65)
print("expected result: 36, actual result: {}".format(test1))

# %%
# each item in the manifest is an item and its weight
manifest = [["bananas", 15], ["mattresses", 34], ["dog kennels",42], ["machine that goes ping!", 120], ["tea chests", 10], ["cheeses", 0]]

cargo_weight = 0
cargo_hold = []

for cargo in manifest:
    #code will produce wrong output if cargo_weight >= 100
    if cargo_weight + cargo[1] >= 100:
        
        break
    else:
        cargo_hold.append(cargo[0])
        cargo_weight += cargo[1]

print(cargo_weight)

print(cargo_hold)
# Out:
# 91
# ['bananas', 'mattresses', 'dog kennels']

# %%
headlines = ["Local Bear Eaten by Man",
             "Legislature Announces New Laws",
             "Peasant Discovers Violence Inherent in System",
             "Cat Rescues Fireman Stuck in Tree",
             "Brave Knight Runs Away",
             "Papperbok Review: Totally Triffic"]


# TODO: set news_ticker to a string that contains no more than 140 characters long.
# HINT: modify the headlines list to verify your loop works with different inputs
news_ticker = ""
res_len = 0
for indx in range(len(headlines)):
    if res_len + len(headlines[indx]) >= 140:
        rem_char = 140 - res_len
        print("rem_char {}".format(rem_char))
        last_str = headlines[indx]
        last_str = last_str[:rem_char]
        print(last_str)
        news_ticker += last_str
        res_len = len(news_ticker)
        break
    else:
        news_ticker += headlines[indx]
        news_ticker += " "
        res_len = len(news_ticker)
        print("inside {}".format(res_len))

print(news_ticker)
print(res_len)
# Out:
# inside 24
# inside 55
# inside 101
# inside 135
# rem_char 5
# Brave
# Local Bear Eaten by Man Legislature Announces New Laws Peasant Discovers Violence Inherent in System Cat Rescues Fireman Stuck in Tree Brave
# 140

# %%
#highly efficient simple version of my code by udacity
for headline in headlines:
    news_ticker += headline + " "
    if len(news_ticker) >= 140:
        news_ticker = news_ticker[:140]
        break

# %%
def comp_ans(myans,actans):
    print(myans)
    print(actans)
    if myans == actans:
        return True
    else:
        return False
        
def check_answers(my_answers,act_answers):
    """
    Checks the five answers provided to a multiple choice quiz and returns the results.
    """
    results = []
    for indx in range(len(my_answers)):
        results.append(comp_ans(my_answers[indx],act_answers[indx]))
    print(results)
    count_correct = 0
    count_incorrect = 0
    for result in results:
        if result:
            count_correct += 1
    print(count_correct)
    print(len(results))
    if float(count_correct)/len(results) > 0.7:
        return "Congratulations, you passed the test! You scored " + str(count_correct) + " out of {}.".format(len(results))
    elif float(len(results))-float(count_correct)/len(results) >= 0.3:
        return "Unfortunately, you did not pass. You scored " + str(count_correct) + " out of {}.".format(len(results))

# %%
my_ans = ["1","test","2","4"]
act_ans = ["1","test","3","5"]

check_answers(my_ans,act_ans)
# Out:
# 1
# 1
# test
# test
# 2
# 3
# 4
# 5
# [True, True, False, False]
# 2
# 4
# 'Unfortunately, you did not pass. You scored 2 out of 4.'

# %%
def check_answer(my_answer, answer):
    if my_answer == answer:
        return True
    else:
        return False

def check_answers(my_answers,answers):
    #Checks the five answers provided to a multiple choice quiz and returns the results.
    results = []
    for i in range(len(my_answers)):
        results.append(check_answer(my_answers[i], answers[i]))
    count_correct = 0

    for result in results:
        if result:
            count_correct += 1

    if count_correct/len(results) > 0.7:
        return "Congratulations, you passed the test!"
    elif (len(results) - count_correct)/len(results) >= 0.3:
        return "Unfortunately, you did not pass."

# %%
my_ans = ["1","test","2","4"]
act_ans = ["1","test","3","5"]

print(check_answers(my_ans,act_ans))
# Out:
# None

# %%
n = 1
while n**2 < 2000:
    squares.add(n**2)
    n += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-a6d443c90232> in <module>()
#       1 n = 1
#       2 while n**2 < 2000:
# ----> 3     squares.add(n**2)
#       4     n += 1
#
# NameError: name 'squares' is not defined

# %%
squares = set()

# todo: populate "squares" with the set of all of the integers less 
# than 2000 that are square numbers


# Note: If you want to call the nearest_square function, you must define
# the function on a line before you call it. Feel free to move this code up!
def nearest_square(limit):
    answer = 0
    ans_set = set()
    while (answer+1)**2 < limit:
        answer += 1
        ans_set.add(answer**2)
    ans_set.add(answer**2)
    return ans_set
    
squares = nearest_square(2000)
print(sorted(squares))
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400, 441, 484, 529, 576, 625, 676, 729, 784, 841, 900, 961, 1024, 1089, 1156, 1225, 1296, 1369, 1444, 1521, 1600, 1681, 1764, 1849, 1936]

# %%
population = {'Shanghai': 17.8,
              'Istanbul': 13.3,
              'Karachi': 13.0,
              'Mumbai': 12.5}

print(population["new jersey"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-23ea834018d9> in <module>()
#       4               'Mumbai': 12.5}
#       5
# ----> 6 print(population["new jersey"])
#
# KeyError: 'new jersey'

# %%
def most_prolific(beat_disc):
    year_rnk = dict()
    for alb in beat_disc:
        if beat_disc[alb] in year_rnk:
            year_rnk[beat_disc[alb]] += 1
        else:
            year_rnk[beat_disc[alb]] = 1
    
    return(max(year_rnk, key = year_rnk.get))
    
    
Beatles_Discography = {"Please Please Me": 1963, "With the Beatles": 1963, 
    "A Hard Day's Night": 1964, "Beatles for Sale": 1964, "Twist and Shout": 1964,
    "Help": 1965, "Rubber Soul": 1965, "Revolver": 1966,
    "Sgt. Pepper's Lonely Hearts Club Band": 1967,
    "Magical Mystery Tour": 1967, "The Beatles": 1968,
    "Yellow Submarine": 1969 ,'Abbey Road': 1969,
    "Let It Be": 1970}

res = most_prolific(Beatles_Discography)
print(res)
max(res, key = res.get)
# Out:
# {1963: 2, 1964: 3, 1965: 2, 1966: 1, 1967: 2, 1968: 1, 1969: 2, 1970: 1}
# 1964

# %%
def most_prolific(discs): 
#We will store a dictionary of years 
#and number of albums per year     
    years = {} 
    maxyears = [] 
    maxnumber = 0 
    for disc in discs: 
        year = discs[disc]
        if year in years: 
            years[year] += 1 
        else: 
            years[year] = 1 

#find the year in which the maximum 
#number of albums was published 
#there are more elegant ways of accomplishing this, 
#but the code below works 
    for year in years:
        if years[year] > maxnumber: 
            maxyears=[] 
            maxyears.append(year) 
            maxnumber = years[year] 
        elif years[year] == maxnumber and not (year in maxyears): 
            maxyears.append(year) 
    if (len(maxyears) == 1): 
        return maxyears[0] 
    else: 
        return maxyears
